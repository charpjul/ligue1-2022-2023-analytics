# %%
import pandas as pd

df = pd.read_csv("../data/raw/MatchDetailStats_20222023.csv", sep=";", encoding="latin1")

df.head()
# Out:
#    MatchId     Journee                                  Stade  Spectateurs  \
# 0    70850  Journée 10                     STADE RAYMOND-KOPA       7970.0
# 1    70851  Journée 10                   STADE FRANCIS-LE BLÉ       9819.0
# 2    70852  Journée 10                 STADE GABRIEL-MONTPIED      11119.0
# 3    70853  Journée 10  DECATHLON ARENA  STADE PIERRE-MAUROY      48527.0
# 4    70854  Journée 10                       GROUPAMA STADIUM      41495.0
#
#                          Date           home_team             away_team  \
# 0  DIM. 9 OCTOBRE 2022- 15:00          ANGERS SCO  RC STRASBOURG ALSACE
# 1  DIM. 9 OCTOBRE 2022- 15:00   STADE BRESTOIS 29            FC LORIENT
# 2  DIM. 9 OCTOBRE 2022- 15:00    CLERMONT FOOT 63            AJ AUXERRE
# 3  DIM. 9 OCTOBRE 2022- 20:45          LOSC LILLE               RC LENS
# 4  VEN. 7 OCTOBRE 2022- 21:00  OLYMPIQUE LYONNAIS           TOULOUSE FC
#
#    home_goal  away_goal home_possession  ... home_tirs away_tirs  \
# 0          2          3            54,5  ...      14.0      15.0
# 1          1          2            50,3  ...      11.0      14.0
# 2          2          1            47,9  ...      10.0      14.0
# 3          1          0            45,3  ...      12.0      10.0
# 4          1          1              58  ...      19.0       5.0
#
#   home_tirs_cadres away_tirs_cadres home_carton_jaune  away_carton_jaune  \
# 0              8.0              7.0               1.0                1.0
# 1              4.0              5.0               3.0                1.0
# 2              6.0              5.0               0.0                0.0
# 3              6.0              3.0               3.0                5.0
# 4              8.0              2.0               2.0                2.0
#
#    home_carton_rouge  away_carton_rouge  home_formation  away_formation
# 0                0.0                0.0       2-2-2-2-2            5-3-2
# 1                0.0                0.0       2-2-2-2-2        3-2-2-2-1
# 2                0.0                0.0       3-2-2-2-1        4-1-2-2-1
# 3                0.0                0.0       2-2-2-3-1        2-2-2-3-1
# 4                0.0                0.0       2-2-2-3-1      2-2-1-2-2-1
#
# [5 rows x 35 columns]

# %%
# Dimensions
df.shape

# Types de colonnes
df.dtypes

# Vérifier les valeurs manquantes
df.isna().sum()

# Statistiques rapides sur les colonnes numériques
df.describe()
# Out:
#             MatchId   Spectateurs   home_goal   away_goal  home_interceptions  \
# count    379.000000    378.000000  379.000000  379.000000          378.000000
# mean   70965.292876  23698.473545    1.485488    1.319261           10.391534
# std      143.310468  15414.649544    1.303912    1.155124            3.931122
# min    70760.000000     40.000000    0.000000    0.000000            2.000000
# 25%    70855.500000  11595.750000    1.000000    0.500000            7.000000
# 50%    70960.000000  18717.500000    1.000000    1.000000           10.500000
# 75%    71054.500000  32153.750000    2.000000    2.000000           13.000000
# max    71530.000000  65894.000000    7.000000    7.000000           23.000000
#
#        away_interceptions  home_hors_jeux  away_hors_eux  home_corners_won  \
# count          378.000000      378.000000     378.000000        378.000000
# mean            10.701058        1.632275       1.571429          5.005291
# std              4.112225        1.348824       1.369012          2.689004
# min              0.000000        0.000000       0.000000          0.000000
# 25%              8.000000        1.000000       0.000000          3.000000
# 50%             10.000000        1.000000       1.000000          5.000000
# 75%             13.000000        2.000000       2.000000          7.000000
# max             25.000000        8.000000       7.000000         15.000000
#
#        away_corners_won  ...  home_centres  away_centres   home_tirs  \
# count        378.000000  ...    378.000000    378.000000  378.000000
# mean           4.291005  ...     17.843915     15.695767   13.023810
# std            2.494551  ...      8.295566      7.495005    4.761357
# min            0.000000  ...      3.000000      2.000000    2.000000
# 25%            3.000000  ...     12.000000     10.000000   10.000000
# 50%            4.000000  ...     16.500000     14.000000   12.000000
# 75%            6.000000  ...     22.000000     20.000000   16.000000
# max           14.000000  ...     49.000000     47.000000   31.000000
#
#         away_tirs  home_tirs_cadres  away_tirs_cadres  home_carton_jaune  \
# count  378.000000        378.000000        378.000000         378.000000
# mean    11.473545          4.793651          4.246032           1.449735
# std      4.762318          2.371305          2.497808           1.164853
# min      1.000000          0.000000          0.000000           0.000000
# 25%      8.000000          3.000000          2.250000           1.000000
# 50%     11.000000          5.000000          4.000000           1.000000
# 75%     14.000000          6.000000          6.000000           2.000000
# max     31.000000         13.000000         15.000000           5.000000
#
#        away_carton_jaune  home_carton_rouge  away_carton_rouge
# count         378.000000         378.000000         378.000000
# mean            1.756614           0.148148           0.108466
# std             1.198594           0.384389           0.343770
# min             0.000000           0.000000           0.000000
# 25%             1.000000           0.000000           0.000000
# 50%             2.000000           0.000000           0.000000
# 75%             2.000000           0.000000           0.000000
# max             5.000000           2.000000           2.000000
#
# [8 rows x 22 columns]
